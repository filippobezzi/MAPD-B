# %% [markdown]
# # Kafka Consumer

# %% [markdown]
# Using the `kafka-python` module, Kafka consumers can be instantiated via the `KafkaConsumer` class:
#
# ```python
# from kafka import KafkaConsumer
#
# # Create a Kafka consumer instance
# consumer = KafkaConsumer(
#     bootstrap_servers=['62.30.10.23:9092'],  # list of brokers
#     security_protocol="SSL",                 # security protocol (if any)
#     ssl_cafile="./ca.pem",                   # certificate details (if any)
#     ssl_certfile="./service.cert",           #           ...
#     ssl_keyfile="./service.key",             #           ...
#     value_deserializer=msgpack.unpackb,      # message value deserialization function (e.g. unpack the message from a specific format)
#     auto_offset_reset='earliest',            # automatically bring the reading offset to the earliest message
#     group_id="group_A",                      # identify this consumer as part of group_A
# )
# ```
#
# Once more, we'll use a simple implementation of the consumer, with no specific configurations used in this example.

# %%
# define the list of brokers in the cluster
KAFKA_BOOTSTRAP_SERVERS = ['kafka-broker:9092']

# %%
from kafka import KafkaConsumer

# create a Kafka consumer instance
consumer = KafkaConsumer(
    bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,  # list of Kafka brokers
    consumer_timeout_ms=10000                   # maximum time to wait for a new message 
                                                # before stopping the consumer
)

# %% [markdown]
# Inspect the available topics on the brokers:

# %%
# list all available topics on the kafka brokers
consumer.topics()
# Out:
# {'my_awesome_topic', 'results'}

# %% [markdown]
# In the Publish/Subscribe (Pub/Sub) model, before consuming messages from a specific topic, you need to subscribe to that topic. By subscribing, the consumer expresses its interest in receiving messages from the specified topic.
#
# It's important to note that subscribing to a topic doesn't immediately consume any messages.
#
# Instead, it establishes a connection between the consumer and the partitions of the subscribed topic hosted on the Kafka brokers. This connection allows the consumer to start polling for messages from those partitions.
#
# Once you have subscribed to the topic, the consumer can start polling for messages, fetching messages from the subscribed partitions and return them to the consumer for further processing.

# %%
# subscribe to a topic
consumer.subscribe(['my_awesome_topic'])

# check the active subscriptions
consumer.subscription()
# Out:
# {'my_awesome_topic'}

# %% [markdown]
# The `KafkaConsumer` class also offers the possibility to inspect topics (for instance, in terms of the number of partitions), but **not** to modify them.
#
# We can inspect how many partitions the specific topic is made of:

# %%
# print the list of partition IDs 
# e.g. a topic with tree partitions will have partition IDs {0, 1, 2}
consumer.partitions_for_topic('my_awesome_topic')
# Out:
# {0}

# %% [markdown]
# We can instruct the consumer to `poll` (i.e., ask for all new messages stored in the topic) with a given cadence or logic.
#
# For instance, we can set the consumer to read only 10 messages at a time, with a timeout between subsequent readouts of a given $\Delta t$.

# %%
# set up the polling strategy for the consumer
consumer.poll(timeout_ms=0,         # do not enable dead-times before one poll to the next
              max_records=None,     # do not limit the number of records to consume at once 
              update_offsets=True   # update the reading offsets on this topic
             )
# Out:
# {}

# %% [markdown]
# Now the consumer is ready to poll messages (until it is stopped or it reaches a timeout).
#
# Let's look for all messages in the consumer:

# %%
# this consumer will keep polling for messages 
# until stopped by the user
# (or reaches the consumer_timeout_ms, if specified)
for message in consumer:
    print (message)

# %% [markdown]
# The reading offset can also be reset to the beginning of the topic, allowing for re-reading the entire topic:

# %%
# go back to the beginning of the topic
consumer.seek_to_beginning()

# read the entire topic and print it out
for message in consumer:
    print (message)
# Out:
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=0, timestamp=1748503346905, timestamp_type=0, key=None, value=b'hey', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=3, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=1, timestamp=1748503348759, timestamp_type=0, key=None, value=b'jude', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=4, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=2, timestamp=1748503351028, timestamp_type=0, key=None, value=b"don't", headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=5, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=3, timestamp=1748503352075, timestamp_type=0, key=None, value=b'mae', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=3, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=4, timestamp=1748503353199, timestamp_type=0, key=None, value=b'it', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=2, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=5, timestamp=1748503354507, timestamp_type=0, key=None, value=b'bad', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=3, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=6, timestamp=1748503436740, timestamp_type=0, key=None, value=b'\xef\xbf\xbd', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=3, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=7, timestamp=1748503437098, timestamp_type=0, key=None, value=b'', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=0, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=8, timestamp=1748503437271, timestamp_type=0, key=None, value=b'', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=0, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=9, timestamp=1748503511484, timestamp_type=0, key=None, value=b'bruh', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=4, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=10, timestamp=1748503517564, timestamp_type=0, key=None, value=b'daje', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=4, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=11, timestamp=1748503785777, timestamp_type=0, key=None, value=b'message 1', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=9, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=12, timestamp=1748503949179, timestamp_type=0, key=None, value=b'a new message', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=13, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=13, timestamp=1748503964055, timestamp_type=0, key=None, value=b'brody', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=5, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=14, timestamp=1748503968329, timestamp_type=0, key=None, value=b'a new message', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=13, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=15, timestamp=1748504044222, timestamp_type=0, key=None, value=b'a message from a newly revived producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=39, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=16, timestamp=1748504264240, timestamp_type=0, key=None, value=b'brody ci sei?', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=13, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=17, timestamp=1748504330137, timestamp_type=0, key=None, value=b'ao', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=2, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=18, timestamp=1748504339759, timestamp_type=0, key=None, value=b'eo', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=2, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=19, timestamp=1748504354464, timestamp_type=0, key=None, value=b'augh', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=4, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=20, timestamp=1748505208958, timestamp_type=0, key=b'some_key', value=b'a message with key', headers=[], checksum=None, serialized_key_size=8, serialized_value_size=18, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=21, timestamp=1748505376655, timestamp_type=0, key=None, value=b'message 1', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=9, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=22, timestamp=1748505376673, timestamp_type=0, key=None, value=b'a new message', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=13, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=23, timestamp=1748505376807, timestamp_type=0, key=None, value=b'a message from a newly revived producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=39, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=24, timestamp=1748505376823, timestamp_type=0, key=b'some_key', value=b'a message with key', headers=[], checksum=None, serialized_key_size=8, serialized_value_size=18, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=25, timestamp=1748505383689, timestamp_type=0, key=None, value=b'message 1', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=9, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=26, timestamp=1748505383705, timestamp_type=0, key=None, value=b'a new message', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=13, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=27, timestamp=1748505383838, timestamp_type=0, key=None, value=b'a message from a newly revived producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=39, serialized_header_size=-1)
# ConsumerRecord(topic='my_awesome_topic', partition=0, leader_epoch=0, offset=28, timestamp=1748505383907, timestamp_type=0, key=b'some_key', value=b'a message with key', headers=[], checksum=None, serialized_key_size=8, serialized_value_size=18, serialized_header_size=-1)

# %% [markdown]
# The message content (`ConsumerRecord`) can be quite messy, but it can be easily inspected by parsing only the relevant information.

# %%
# import packages to interpret dates
from datetime import datetime

# go back to the beginning of the topic
consumer.seek_to_beginning()

# break down the message into its main components
for message in consumer:
    print ("%d[%d] @%s k=%s v=%s" % (message.partition,
                          message.offset,
                          datetime.fromtimestamp(message.timestamp/1000).time(),
                          message.key,
                          message.value))
# Out:
# 0[0] @07:22:26.905000 k=None v=b'hey'
# 0[1] @07:22:28.759000 k=None v=b'jude'
# 0[2] @07:22:31.028000 k=None v=b"don't"
# 0[3] @07:22:32.075000 k=None v=b'mae'
# 0[4] @07:22:33.199000 k=None v=b'it'
# 0[5] @07:22:34.507000 k=None v=b'bad'
# 0[6] @07:23:56.740000 k=None v=b'\xef\xbf\xbd'
# 0[7] @07:23:57.098000 k=None v=b''
# 0[8] @07:23:57.271000 k=None v=b''
# 0[9] @07:25:11.484000 k=None v=b'bruh'
# 0[10] @07:25:17.564000 k=None v=b'daje'
# 0[11] @07:29:45.777000 k=None v=b'message 1'
# 0[12] @07:32:29.179000 k=None v=b'a new message'
# 0[13] @07:32:44.055000 k=None v=b'brody'
# 0[14] @07:32:48.329000 k=None v=b'a new message'
# 0[15] @07:34:04.222000 k=None v=b'a message from a newly revived producer'
# 0[16] @07:37:44.240000 k=None v=b'brody ci sei?'
# 0[17] @07:38:50.137000 k=None v=b'ao'
# 0[18] @07:38:59.759000 k=None v=b'eo'
# 0[19] @07:39:14.464000 k=None v=b'augh'
# 0[20] @07:53:28.958000 k=b'some_key' v=b'a message with key'
# 0[21] @07:56:16.655000 k=None v=b'message 1'
# 0[22] @07:56:16.673000 k=None v=b'a new message'
# 0[23] @07:56:16.807000 k=None v=b'a message from a newly revived producer'
# 0[24] @07:56:16.823000 k=b'some_key' v=b'a message with key'
# 0[25] @07:56:23.689000 k=None v=b'message 1'
# 0[26] @07:56:23.705000 k=None v=b'a new message'
# 0[27] @07:56:23.838000 k=None v=b'a message from a newly revived producer'
# 0[28] @07:56:23.907000 k=b'some_key' v=b'a message with key'
# 0[29] @08:05:12.323000 k=None v=b'message 1'
# 0[30] @08:05:12.340000 k=None v=b'a new message'
# 0[31] @08:05:12.478000 k=None v=b'a message from a newly revived producer'
# 0[32] @08:05:12.489000 k=b'some_key' v=b'a message with key'

# %% [markdown]
# Let's change the topic to which the consumer is subscribed and make it a partitioned one:

# %%
# subscribe to a partitioned topic
consumer.subscribe(['a_partitioned_topic'])
consumer.subscription()
# Out:
# {'a_partitioned_topic'}

# %% [markdown]
# By inspecting the number of partitions for this topic, we can now see that there are 2 partitions: partition #0 and partition #1.

# %%
# check the partitions in the partitioned topic
consumer.partitions_for_topic('a_partitioned_topic')
# Out:
# set()

# %% [markdown]
# When reading from a partitioned topic, it's easy to observe that the messages are sent to the two partitions in a seemingly arbitrary way.

# %%
# import json to unpack json strings
import json

# go back to the beginning of the topic
consumer.seek_to_beginning()

# read messages from the beginning of the topic
# decode the json into the python dictionary format
for message in consumer:
    print(f"{message.partition}[{message.offset}]\t {json.loads(message.value)}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 5
#       2 import json
#       4 # go back to the beginning of the topic
# ----> 5 consumer.seek_to_beginning()
#       7 # read messages from the beginning of the topic
#       8 # decode the json into the python dictionary format
#       9 for message in consumer:
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/group.py:874, in KafkaConsumer.seek_to_beginning(self, *partitions)
#     872 if not partitions:
#     873     partitions = self._subscription.assigned_partitions()
# --> 874     assert partitions, 'No partitions are currently assigned'
#     875 else:
#     876     for p in partitions:
#
# AssertionError: No partitions are currently assigned

# %% [markdown]
# ## Creating a Consumer Accessing Only One Partition
#
# Publishing records to a partitioned topic is typically transparent to the user: the producer publishes to the topic, and the Kafka cluster will redirect the message to the partition leader, later replicating it to the followers.
#
# The same applies to a generic consumer. As we have just seen, data is consumed from all partitions within the topic.
#
# In some cases, however, it may be more suitable to instantiate multiple consumers, with each one reading from a specific partition of a topic.
#
# Let's create a consumer specifically designed to access the data from partition #0 of the previous partitioned topic.

# %%
# import TopicPartition to be able to assign a partition to a consumer
from kafka import TopicPartition

# create a standard consumer with a timeout of 10 seconds
consumer_part_0 = KafkaConsumer(bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
                                client_id='consumer_n_0',
                                consumer_timeout_ms=10000)

# assign the consumer to a specific topic-partition combination
consumer_part_0.assign([TopicPartition(topic     = 'a_partitioned_topic', # topic
                                       partition = 0                      # partition id
                                      )]
                      )

# %%
# go back to the beginning of the topic (for this specific partition)
consumer_part_0.seek_to_beginning()

# read messages from the beginning of the topic (for this specific partition)
# decode the json into the python dictionary format
for message in consumer_part_0:
    print(f"{message.partition}[{message.offset}]\t {json.loads(message.value)}")

# %% [markdown]
# ## Creating a Consumer Group
#
# Multiple consumers can read from the same topic.
#
# In Kafka, every consumer is part of a consumer group (even a single consumer is part of its own consumer group).
#
# A consumer group consists of one or more cooperating consumers that gather data from the same topic. The consumer group dynamically balances the load across its members and redistributes the consume calls.
#
# If a consumer within a consumer group fails, the remaining consumers in the same group will continue to read the entire data from the subscribed topic.

# %%
# create `consumer_one` to read from a specific partition
# assign this consumer to a group
consumer_one = KafkaConsumer(bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
                             client_id='consumer_one',
                             group_id='my_group',                       # the same group will be used by all consumers
                             auto_offset_reset='earliest',
                             consumer_timeout_ms=10000)

# %%
# subscribe `consumer_one` to the partitioned topic
consumer_one.subscribe(['a_partitioned_topic'])

# %% [markdown]
# ---
#
# ### Consuming messages as a group
# Use the `ConsumerGroup` notebook to:
# 1. create a second consumer `consumer_two`
# 2. assign it to the same consumer group `my_group`
# 3. subscribe to the same topic `a_partitioned_topic`

# %% [markdown]
# Each consumer within a group is going to be an independent process (should be run in parallel from the others) and will provide access to a fraction of the incoming data

# %%
# check the partitions assigned to `consumer_one`
consumer_one.assignment()
# Out:
# set()

# %% [markdown]
# Start the two consumers and process data in parallel from the two partitions.
#
# Typically, one would achieve this by running the two consumers in separate threads, processes, or executors, depending on the desired computing architecture.

# %%
# use multiple consumers in parallel (`consumer_one` in this notebook)
for message in consumer_one:
    print(f"{message.partition}[{message.offset}]\t {json.loads(message.value)}")

# %%
# check the partitions assigned to `consumer_one`
consumer_one.assignment()
# Out:
# {TopicPartition(topic='a_partitioned_topic', partition=0)}

# %% [markdown]
# ---
#
# ## Reading from the Kafka+Spark results topic
#
# Let's subscribe to the `results` topic and monitor the frauds

# %%
consumer.subscribe(['results'])

for message in consumer:
    print ("%d[%d] k=%s v=%s" % (message.partition,
                          message.offset,
                          message.key,
                          message.value))
    print ('      --> sending alert message to user {}\n'.format(message.key.decode('ascii')))
